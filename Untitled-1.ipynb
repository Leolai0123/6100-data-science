# %%
df = pd.read_csv('https://raw.githubusercontent.com/delinai/schulich_ds1/main/Datasets/kc_house_data.csv')

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.iloc[:,11:]
# Out:
#        grade  sqft_above  sqft_basement  yr_built  yr_renovated  zipcode  \
# 0          7        1180              0      1955             0    98178
# 1          7        2170            400      1951          1991    98125
# 2          6         770              0      1933             0    98028
# 3          7        1050            910      1965             0    98136
# 4          8        1680              0      1987             0    98074
# ...      ...         ...            ...       ...           ...      ...
# 21608      8        1530              0      2009             0    98103
# 21609      8        2310              0      2014             0    98146
# 21610      7        1020              0      2009             0    98144
# 21611      8        1600              0      2004             0    98027
# 21612      7        1020              0      2008             0    98144
#
#            lat     long  sqft_living15  sqft_lot15
# ...

# %%
print(df.dtypes)
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
plt.hist(df['price'])
# Out:
# (array([1.9021e+04, 2.1480e+03, 3.1600e+02, 9.0000e+01, 2.6000e+01,
#         4.0000e+00, 4.0000e+00, 1.0000e+00, 1.0000e+00, 2.0000e+00]),
#  array([  75000.,  837500., 1600000., 2362500., 3125000., 3887500.,
#         4650000., 5412500., 6175000., 6937500., 7700000.]),
#  <BarContainer object of 10 artists>)

# %%
df[df['bedrooms']==33]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 15870  2402100895  20140625T000000  640000.0        33       1.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 15870         1620      6000     1.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 15870        1040            580      1947             0    98103  47.6878
#
#           long  sqft_living15  sqft_lot15
# 15870 -122.331           1330        4700
#
# [1 rows x 21 columns]

# %%
df['bedrooms'] = df['bedrooms'].replace(33.3)
# Out:
# C:\Users\think\AppData\Local\Temp\ipykernel_23404\1640757447.py:1: FutureWarning: Series.replace without 'value' and with non-dict-like 'to_replace' is deprecated and will raise in a future version. Explicitly specify the new values instead.
#   df['bedrooms'] = df['bedrooms'].replace(33.3)

# %%
df[df['bathrooms'] > 3.5].describe()
# Out:
#                  id         price    bedrooms   bathrooms   sqft_living  \
# count  5.570000e+02  5.570000e+02  557.000000  557.000000    557.000000
# mean   3.835341e+09  1.440567e+06    4.701975    4.268851   4400.797127
# std    2.824372e+09  9.427293e+05    1.051316    0.612265   1391.095737
# min    4.200013e+07  2.550000e+05    3.000000    3.750000   1390.000000
# 25%    1.454600e+09  8.500000e+05    4.000000    3.750000   3530.000000
# 50%    3.262301e+09  1.169000e+06    5.000000    4.000000   4210.000000
# 75%    5.700004e+09  1.750000e+06    5.000000    4.500000   5040.000000
# max    9.831200e+09  7.700000e+06   10.000000    8.000000  13540.000000
#
#             sqft_lot      floors  waterfront        view   condition  \
# count     557.000000  557.000000  557.000000  557.000000  557.000000
# mean    32922.026930    1.954219    0.046679    0.915619    3.267504
# std     78642.846485    0.416785    0.211139    1.413599    0.567624
# ...

# %%
values_to_replace_max = df[df['bathrooms'] > 3.5].index

# %%
df.loc[values_to_replace_max,'bathrooms'] = 3.5

# %%
df[df['bathrooms'] > 3.5]
# Out:
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []
#
# [0 rows x 21 columns]

# %%
df.loc[values_to_replace_max] ['bathrooms'] = 3.5

# %%
df[df['bathrooms']>3.5]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 75     3276920270  20141105T000000   832500.0         4       4.00
# 235    1762600320  20140610T000000  1025000.0         5       4.00
# 270    4054500390  20141007T000000  1365000.0         4       4.75
# 300    3225069065  20140624T000000  3075000.0         4       5.00
# ...           ...              ...        ...       ...        ...
# 21551  1561750040  20141224T000000  1375000.0         5       4.50
# 21561  6664500090  20150115T000000   750000.0         5       4.00
# 21576  9253900271  20150107T000000  3567000.0         5       4.50
# 21593  8672200110  20150317T000000  1088000.0         5       3.75
# 21600   249000205  20141015T000000  1537000.0         5       3.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 5             5420    101930     1.0           0     0  ...     11
# ...

# %%
# which of these variables is the output variable? and which are inputs?
# develop some hypotheses > what might we be interested in understanding? 
# what do you think is the relationship between inputs and output?

# %%
example_list = [9,10,34,87,98]

# %%
example_list.sort()

# %%
pip install scipy
# Out:
# ...
# [notice] A new release of pip available: 22.3 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
from scipy import stats

# %%
df[df['bathrooms'] > 3.5]
# Out:
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []
#
# [0 rows x 21 columns]

# %%
sns.boxplot(df['sqft_living'])
# Out:
# <Axes: ylabel='sqft_living'>

# %%
df['sqft_living_winsorized'] = stats.mstats.winsorize(df['sqft_living'], limits=[0,0.01])

# %%
df[['sqft_living','sqft_living_winsorized']].sort_values('sqft_living', ascending=False)
# Out:
#        sqft_living  sqft_living_winsorized
# 12777        13540                    4980
# 7252         12050                    4980
# 3914         10040                    4980
# 9254          9890                    4980
# 8092          9640                    4980
# ...            ...                     ...
# 4868           390                     390
# 18379          384                     384
# 860            380                     380
# 15381          370                     370
# 19452          290                     290
#
# [21613 rows x 2 columns]

# %%
plt.figure(figsize = (20,20))
sns.heatmap(df.iloc[:,2:].corr(), annot=True)
# Out:
# <Axes: >

# %%
sns.boxplot(x=df['view'], y=df['price'])
# Out:
# <Axes: xlabel='view', ylabel='price'>
